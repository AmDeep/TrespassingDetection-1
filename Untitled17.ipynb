# %%
import cv2

cam = cv2.VideoCapture(0)

cv2.namedWindow("test")

img_counter = 0

while True:
    ret, frame = cam.read()
    cv2.imshow("test", frame)
    if not ret:
        break
    k = cv2.waitKey(1)

    if k%256 == 27:
        # ESC pressed
        print("Escape hit, closing...")
        break
    elif k%256 == 32:
        # SPACE pressed
        img_name = "opencv_frame_{}.png".format(img_counter)
        cv2.imwrite(img_name, frame)
        print("{} written!".format(img_name))
        img_counter += 1

cam.release()

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-0a6fb659d638> in <module>()
#       9 while True:
#      10     ret, frame = cam.read()
# ---> 11     cv2.imshow("test", frame)
#      12     if not ret:
#      13         break
#
# error: OpenCV(4.1.2) C:\projects\opencv-python\opencv\modules\highgui\src\window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
# !pip install pyautogui
# Out:
# ...
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.48-py2-none-any.whl size=37324 sha256=1a945f8f65f9432111c26dda55d05332fc016721cb20e861dc511cf8d3c9e203
#   Stored in directory: c:\users\amardeep\appdata\local\pip\cache\wheels\67\d9\0c\439081e465056b377cf4a8a5761d9dff6ad7482734e6503694
# ...
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.7-py2-none-any.whl size=7345 sha256=d694f3bbd3ba166b0de04c64ee9a364daf25d92595db44e41039038a3243133e
#   Stored in directory: c:\users\amardeep\appdata\local\pip\cache\wheels\85\ca\c2\4b2d60ca17890e1b5b872f62d674dd503d3734c09ab2bb2d26
# ...
#   Created wheel for PyTweening: filename=PyTweening-1.0.3-py2-none-any.whl size=3831 sha256=a13e9bfc0ff7659d810bf5b96309c3fdd47d852217e7ac2f40707962297d0c27
#   Stored in directory: c:\users\amardeep\appdata\local\pip\cache\wheels\69\ae\c6\be02145c03c64f3c5fbaf4b2f7907fd522fc86e0620cd34790
# ...

# %%
# !pip install imutils
# Out:
# ...
#   Created wheel for imutils: filename=imutils-0.5.3-py2-none-any.whl size=25879 sha256=e4b4d9947d93e930a1ad7e6cdd20b9b7301f10edb36f94ee9976c4390c69656c
#   Stored in directory: c:\users\amardeep\appdata\local\pip\cache\wheels\0b\de\d5\3ac374c576992f134c6a5243c4fb1fcbbcf863fe810aac9f30
# Successfully built imutils
# ...
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. A future version of pip will drop support for Python 2.7. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support

# %%
import numpy as np
import pyautogui
import imutils
import cv2

# %%
# take a screenshot of the screen and store it in memory, then
# convert the PIL/Pillow image to an OpenCV compatible NumPy array
# and finally write the image to disk
image = pyautogui.screenshot()
image = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
cv2.imwrite("C:\Users\Amardeep\Downloads\in_memory_to_disk.png", image)
# Out:
# True

# %%
# this time take a screenshot directly to disk
pyautogui.screenshot("C:\Users\Amardeep\Downloads\straight_to_disk.png")
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x4B97668>

# %%
# we can then load our screenshot from disk in OpenCV format
image = cv2.imread("C:\Users\Amardeep\Downloads\straight_to_disk.png")
cv2.imshow("Screenshot", imutils.resize(image, width=600))
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-d95378f267a6> in <module>()
#       1 # we can then load our screenshot from disk in OpenCV format
#       2 image = cv2.imread("C:\Users\Amardeep\Downloads\straight_to_disk.png")
# ----> 3 cv2.imshow("Screenshot", imutils.resize(image, width=600))
#       4 cv2.waitKey(0)
#
# C:\Users\Amardeep\Anaconda2\lib\site-packages\imutils\convenience.pyc in resize(image, width, height, inter)
#      67     # grab the image size
#      68     dim = None
# ---> 69     (h, w) = image.shape[:2]
#      70
#      71     # if both the width and height are None, then return the
#
# AttributeError: 'NoneType' object has no attribute 'shape'
